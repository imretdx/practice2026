// %%
#r "nuget:ScottPlot, 5.0.*"

// %%
using ScottPlot; double[] times = { 32.4, 18.0, 12.4, 8.0 }; double[] threads = { 1, 2, 4, 8 }; Plot plt = new(); plt.Add.Scatter(times, threads); plt.Title("Benchmark"); plt
